# %%
import pandas as pd
import sys
import os
sys.path.append(os.path.abspath(os.path.join('..')))
from scripts.portfolio_optimization import *

# %%
forecast_df_tsla = pd.read_csv("../data/TSLA_forcasted_data.csv")
forecast_df_bnd = pd.read_csv("../data/SPY_forcasted_data.csv")
forecast_df_spy = pd.read_csv("../data/BND_forcasted_data.csv")

# %%
optimizer = PortfolioOptimizer(forecast_df_tsla, forecast_df_bnd, forecast_df_spy)

# %%
optimized_weights, max_sharpe_ratio = optimizer.optimize_portfolio()

# %%
optimizer.plot_portfolio_performance(optimized_weights)
